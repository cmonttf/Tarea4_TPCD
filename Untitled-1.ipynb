# %%
import pandas as pd
import numpy as np
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('winequality(limpio).csv')
df_red = df[df['Red']==1]
df_red['density-kg/m^3']=df_red['density-kg/m^3']/1000
df_red.rename(columns={'density-kg/m^3':'density'}, inplace=True)
df_red
# Out:
# C:\Users\pc0114\AppData\Local\Temp/ipykernel_4116/1349203476.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_red['density-kg/m^3']=df_red['density-kg/m^3']/1000
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                    11.0              0.064516  3.51       0.56      9.4
# 1                    25.0              0.140553  3.20       0.68      9.8
# 2                    15.0              0.110599  3.26       0.65      9.8
# 3                    17.0              0.124424  3.16       0.58      9.8
# 4                    11.0              0.064516  3.51       0.56      9.4
# ...                   ...                   ...   ...        ...      ...
# 1594                 32.0              0.087558  3.45       0.58     10.5
# 1595                 39.0              0.103687  3.52       0.76     11.2
# 1596                 29.0              0.078341  3.42       0.75     11.0
# 1597                 32.0              0.087558  3.57       0.71     10.2
# 1598                 18.0              0.082949  3.39       0.66     11.0
#
#       quality  density quality classification  Red  White
# 0           5  0.99780                   Mala    1      0
# 1           5  0.99680                   Mala    1      0
# 2           5  0.99700                   Mala    1      0
# 3           6  0.99800                  Media    1      0
# 4           5  0.99780                   Mala    1      0
# ...       ...      ...                    ...  ...    ...
# 1594        5  0.99490                   Mala    1      0
# 1595        6  0.99512                  Media    1      0
# 1596        6  0.99574                  Media    1      0
# 1597        5  0.99547                   Mala    1      0
# 1598        6  0.99549                  Media    1      0
#
# [1599 rows x 15 columns]

# %%
df.dtypes
df.describe().T
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         6497.0    7.215307   1.296434    3.800    6.400000
# volatile acidity      6497.0    0.339666   0.164636    0.080    0.230000
# citric acid           6497.0    0.318633   0.145318    0.000    0.250000
# residual sugar        6497.0    5.411317   4.717920    0.600    1.800000
# chlorides             6497.0    0.056034   0.035034    0.009    0.038000
# free sulfur dioxide   6497.0   30.525319  17.749400    1.000   17.000000
# total sulfur dioxide  6497.0    0.252868   0.130235    0.000    0.163594
# pH                    6497.0    3.218501   0.160787    2.720    3.110000
# sulphates             6497.0    0.531268   0.148806    0.220    0.430000
# alcohol               6497.0   10.489136   1.189285    8.000    9.500000
# quality               6497.0    5.818378   0.873255    3.000    5.000000
# density-kg/m^3        6497.0  994.559855   2.790538  987.110  992.340000
# Red                   6497.0    0.246114   0.430779    0.000    0.000000
# White                 6497.0    0.753886   0.430779    0.000    1.000000
#
#                              50%         75%       max
# fixed acidity           7.000000    7.700000    15.900
# volatile acidity        0.290000    0.400000     1.580
# citric acid             0.310000    0.390000     1.660
# residual sugar          3.000000    8.000000    65.800
# chlorides               0.047000    0.065000     0.611
# free sulfur dioxide    29.000000   41.000000   289.000
# total sulfur dioxide    0.258065    0.345622     1.000
# pH                      3.210000    3.320000     4.010
# sulphates               0.510000    0.600000     2.000
# alcohol                10.300000   11.300000    14.900
# quality                 6.000000    6.000000     9.000
# density-kg/m^3        994.800000  996.800000  1000.000
# Red                     0.000000    0.000000     1.000
# White                   1.000000    1.000000     1.000

# %%
plt.figure(figsize = (18,10))
sns.heatmap(df_red.corr(),annot=True,fmt='.2f',linewidths =1)

plt.show()

correlacion = df_red.corr()
correlacion['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.475297
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# total sulfur dioxide   -0.185100
# density                -0.197448
# volatile acidity       -0.390558
# Red                          NaN
# White                        NaN
# Name: quality, dtype: float64

# %%
La variable a predecir sera la calidad

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

sns.scatterplot(ax = axes[0],
                x = "alcohol",
                y = "quality",
                data = df_red).set(title = "Relacion azucar resdual y calidad");

sns.scatterplot(ax = axes[1],
                x = "sulphates",
                y = "quality",
                data = df_red).set(title = "Relacion Sulfatos y calidad");

sns.scatterplot(ax = axes[2],
                x = "citric acid",
                y = "quality",
            data = df_red).set(title = "Relacion Acidez Citrica y calidad");

sns.scatterplot(ax = axes[3],
                x = "fixed acidity",
                y = "quality",
                data = df_red).set(title = "Relacion Acidez Fija y calidad");

# %%
df_red = df_red.drop('Red', axis = 1)
df_red = df_red.drop('White', axis = 1)
df_red = df_red.drop('quality classification', axis = 1)
X = df_red.drop('quality', axis = 1)
df_red
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                    11.0              0.064516  3.51       0.56      9.4
# 1                    25.0              0.140553  3.20       0.68      9.8
# 2                    15.0              0.110599  3.26       0.65      9.8
# 3                    17.0              0.124424  3.16       0.58      9.8
# 4                    11.0              0.064516  3.51       0.56      9.4
# ...                   ...                   ...   ...        ...      ...
# 1594                 32.0              0.087558  3.45       0.58     10.5
# 1595                 39.0              0.103687  3.52       0.76     11.2
# 1596                 29.0              0.078341  3.42       0.75     11.0
# 1597                 32.0              0.087558  3.57       0.71     10.2
# 1598                 18.0              0.082949  3.39       0.66     11.0
#
#       density
# 0     0.99780
# 1     0.99680
# 2     0.99700
# 3     0.99800
# 4     0.99780
# ...       ...
# 1594  0.99490
# 1595  0.99512
# 1596  0.99574
# 1597  0.99547
# 1598  0.99549
#
# [1599 rows x 11 columns]

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
Z = df_red[['alcohol', 'sulphates', 'citric acid', 'fixed acidity']]
lm.fit(Z, df_red['quality'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 1.135864517893726

# %%
lm.coef_
# Out:
# array([0.34603281, 0.82847467, 0.31068805, 0.03175912])

# %% [markdown]
# Como se vio anteriormente, se debería obtener una función lineal final con la estructura:
# $$
# \hat{Y} = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$
# Así, para este caso en particular se obtiene la siguiente función lineal:
# $$
# \hat{quality} = 1.135864517893726 + 0.34603281 \times alchool +  0.82847467  \times sulphates + 0.31068805 \times citric acid + 0.03175912 \times fixed acidity
# $$

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(10, 12))

ax1 = sns.kdeplot(df['quality'], color="r", label="Valor Actual")
sns.kdeplot(Y_hat, color="b", label="Valores Ajustados" , ax=ax1)

plt.title('Valores Actuales vs Ajustados para la calidad')
plt.xlabel('Calidad')
plt.ylabel('nose')

plt.legend(loc='upper right')

plt.show()
plt.close()

# %%
# ajustar el modelo 
lm.fit(Z, df_red['quality'])
# encontrar el R^2
print('El valor de R-cuadrado es: ', lm.score(Z, df_red['quality']))
# Out:
# El valor de R-cuadrado es:  0.28544441192585623
